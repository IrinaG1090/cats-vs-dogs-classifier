# %%
# 03_check_data.ipynb
import os

base_path = r'D:\Projects\image-classification\data'

train_cats = os.path.join(base_path, 'train/cats')
train_dogs = os.path.join(base_path, 'train/dogs')
val_cats = os.path.join(base_path, 'validation/cats')
val_dogs = os.path.join(base_path, 'validation/dogs')

print(f"Кошек в train: {len(os.listdir(train_cats))}")
print(f"Собак в train: {len(os.listdir(train_dogs))}")
print(f"Кошек в validation: {len(os.listdir(val_cats))}")
print(f"Собак в validation: {len(os.listdir(val_dogs))}")
# Out:
# Кошек в train: 10000
# Собак в train: 10000
# Кошек в validation: 2501
# Собак в validation: 2501
